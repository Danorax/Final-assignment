# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <p><strong>Daniel Favale Espinosa</strong></p><wbr><i>Passionate data science student.</i><wbr>

# %% [markdown]
# <em>I am interested in data science to find solutions to social problems and opportunities for improvement that generate sustainable growth.</em>

# %% [markdown]
# <H3>The code bellow take the sides of a rectangle and find its area.</H3>

# %%
width = 2
height = 4
area = width*height
print("The Area of the rectangle is: " + str(area) + " inches")
# Out:
# The Area of the rectangle is: 8 inches

# %% [markdown]
#  <H2>Grandmother's recipe</H2>
#  <img src="https://i0.wp.com/www.marubotana.tv/wp-content/uploads/2014/09/torta-de-la-abuela.jpg?w=1024&ssl=1">
# </img>
#  <H4>Ingredients:</H4>
#  <ul>
#   <li>100g butter</li>
#   <li>1 cup of sugar</li>
#   <li>2 eggs</li>
#   <li>Lemon or orange zest</li>
#   <li>1 cup of milk</li>
#   <li>2 cups flour</li>
#   <li>2 tsp. of baking powder</li>
#     <li><del>c/n icing sugar</del></li>
# </ul>
#
# <a href="https://www.marubotana.tv/recipe-items/torta-deliciosa-de-abuelita/">Go to the secret!!!</a>
